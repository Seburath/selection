# %% [markdown]
# # Aplicacion Freddy Abad
# #### Mi propuesta de solucion del problema propuesto simplifica el codigo con el uso de Clases, adicionalmente le da nombres con valor a las variables puesto que muchas variables carecian de sentido, ademas de eliminar variables y lineas innecesarias
#
# #### My proposed solution to the proposed problem simplifies the code with the use of Classes, additionally it gives names with value to the variables since many variables were meaningless, in addition to eliminating unnecessary variables and lines

# %%
import requests
import csv
from bs4 import BeautifulSoup
import os
import pandas as pd 

file = open('symbols.csv', 'w')
file.truncate()
writer = csv.writer(file)
values_exchange = []

class Exchange:
    def __init__(self,url,page_max,ran_endC,name_exchange):
        self.url=url
        self.page_max=page_max
        self.ran_endC=ran_endC
        self.name_exchange=name_exchange
        
    def extract_data(self):
        for page in range(1, self.page_max):
            response  = requests.get(self.url + str(page))
            data = response.text
            soup = BeautifulSoup(data, features='lxml')
            html = str(soup.contents)
            html_preprocess = html.split('<td>')
            if page < self.page_max-1:
                ran_ini = 3
                ran_end = 400
            else:
                ran_ini = 3
                ran_end = self.ran_endC
            for i in range(ran_ini,ran_end)[0::4]:
                values = (html_preprocess[i][:-6], 'STK', 'SMART', html_preprocess[i+1][:3])
                if values not in values_exchange:
                    print(i, self.name_exchange, values)
                    values_exchange.append(values)

urls=['https://www.interactivebrokers.com/en/index.php?f=2222&exch=nasdaq&showcategories=STK&p=&cc=&limit=100&page=','https://www.interactivebrokers.com/en/index.php?f=2222&exch=nyse&showcategories=STK&p=&cc=&limit=100&page=','https://www.interactivebrokers.com/en/index.php?f=2222&exch=amex&showcategories=STK&p=&cc=&limit=100&page=']
exchange_nasdaq=Exchange(urls[0],35,15,'NASDAQ')                    
exchange_nasdaq.extract_data()

exchange_nyse=Exchange(urls[1],87,372,'NYSE')                    
exchange_nyse.extract_data()

exchange_amex=Exchange(urls[2],87,368,'AMEX')                    
exchange_amex.extract_data()
# Out:
# 3 NASDAQ ('AABA', 'STK', 'SMART', 'USD')
# 7 NASDAQ ('AAL', 'STK', 'SMART', 'USD')
# 11 NASDAQ ('AAME', 'STK', 'SMART', 'USD')
# 15 NASDAQ ('AAOI', 'STK', 'SMART', 'USD')
# 19 NASDAQ ('AAON', 'STK', 'SMART', 'USD')
# 23 NASDAQ ('AAPL', 'STK', 'SMART', 'USD')
# 27 NASDAQ ('AAWW', 'STK', 'SMART', 'USD')
# 31 NASDAQ ('AAXJ', 'STK', 'SMART', 'USD')
# 35 NASDAQ ('AAXN', 'STK', 'SMART', 'USD')
# 39 NASDAQ ('ABCB', 'STK', 'SMART', 'USD')
# 43 NASDAQ ('ABDC', 'STK', 'SMART', 'USD')
# 47 NASDAQ ('ABEO', 'STK', 'SMART', 'USD')
# 51 NASDAQ ('ABIL', 'STK', 'SMART', 'USD')
# 55 NASDAQ ('ABIO', 'STK', 'SMART', 'USD')
# 59 NASDAQ ('ABMD', 'STK', 'SMART', 'USD')
# 63 NASDAQ ('ABTX', 'STK', 'SMART', 'USD')
# 67 NASDAQ ('ABUS', 'STK', 'SMART', 'USD')
# 71 NASDAQ ('ACAD', 'STK', 'SMART', 'USD')
# 75 NASDAQ ('ACAM', 'STK', 'SMART', 'USD')
# 79 NASDAQ ('ACAMU', 'STK', 'SMART', 'USD')
# 83 NASDAQ ('ACBI', 'STK', 'SMART', 'USD')
# 87 NASDAQ ('ACER', 'STK', 'SMART', 'USD')
# 91 NASDAQ ('ACGL', 'STK', 'SMART', 'USD')
# 95 NASDAQ ('ACGLO', 'STK', 'SMART', 'USD')
# 99 NASDAQ ('ACGLP', 'STK', 'SMART', 'USD')
# 103 NASDAQ ('ACHC', 'STK', 'SMART', 'USD')
# 107 NASDAQ ('ACHN', 'STK', 'SMART', 'USD')
# 111 NASDAQ ('ACHV', 'STK', 'SMART', 'USD')
# 115 NASDAQ ('ACIA', 'STK', 'SMART', 'USD')
# 119 NASDAQ ('ACIU', 'STK', 'SMART', 'USD')
# 123 NASDAQ ('ACIW', 'STK', 'SMART', 'USD')
# 127 NASDAQ ('ACLS', 'STK', 'SMART', 'USD')
# 131 NASDAQ ('ACMR', 'STK', 'SMART', 'USD')
# 135 NASDAQ ('ACNB', 'STK', 'SMART', 'USD')
# 139 NASDAQ ('ACOR', 'STK', 'SMART', 'USD')
# 143 NASDAQ ('ACRS', 'STK', 'SMART', 'USD')
# 147 NASDAQ ('ACRX', 'STK', 'SMART', 'USD')
# 151 NASDAQ ('ACST', 'STK', 'SMART', 'USD')
# 155 NASDAQ ('ACT', 'STK', 'SMART', 'USD')
# 159 NASDAQ ('ACTG', 'STK', 'SMART', 'USD')
# 163 NASDAQ ('ACTT', 'STK', 'SMART', 'USD')
# 167 NASDAQ ('ACTTU', 'STK', 'SMART', 'USD')
# 171 NASDAQ ('ACWI', 'STK', 'SMART', 'USD')
# 175 NASDAQ ('ACWX', 'STK', 'SMART', 'USD')
# 179 NASDAQ ('ADAP', 'STK', 'SMART', 'USD')
# 183 NASDAQ ('ADBE', 'STK', 'SMART', 'USD')
# 187 NASDAQ ('ADES', 'STK', 'SMART', 'USD')
# 191 NASDAQ ('ADI', 'STK', 'SMART', 'USD')
# 195 NASDAQ ('ADIL', 'STK', 'SMART', 'USD')
# 199 NASDAQ ('ADMA', 'STK', 'SMART', 'USD')
# 203 NASDAQ ('ADMP', 'STK', 'SMART', 'USD')
# 207 NASDAQ ('ADMS', 'STK', 'SMART', 'USD')
# 211 NASDAQ ('ADP', 'STK', 'SMART', 'USD')
# 215 NASDAQ ('ADPT', 'STK', 'SMART', 'USD')
# 219 NASDAQ ('ADRA', 'STK', 'SMART', 'USD')
# 223 NASDAQ ('ADRD', 'STK', 'SMART', 'USD')
# 227 NASDAQ ('ADRE', 'STK', 'SMART', 'USD')
# 231 NASDAQ ('ADRO', 'STK', 'SMART', 'USD')
# 235 NASDAQ ('ADRU', 'STK', 'SMART', 'USD')
# 239 NASDAQ ('ADSK', 'STK', 'SMART', 'USD')
# 243 NASDAQ ('ADTN', 'STK', 'SMART', 'USD')
# 247 NASDAQ ('ADUS', 'STK', 'SMART', 'USD')
# 251 NASDAQ ('ADVM', 'STK', 'SMART', 'USD')
# 255 NASDAQ ('ADXS', 'STK', 'SMART', 'USD')
# 259 NASDAQ ('AEGN', 'STK', 'SMART', 'USD')
# 263 NASDAQ ('AEHR', 'STK', 'SMART', 'USD')
# 267 NASDAQ ('AEIS', 'STK', 'SMART', 'USD')
# 271 NASDAQ ('AEMD', 'STK', 'SMART', 'USD')
# 275 NASDAQ ('AERI', 'STK', 'SMART', 'USD')
# 279 NASDAQ ('AESE', 'STK', 'SMART', 'USD')
# 283 NASDAQ ('AEY', 'STK', 'SMART', 'USD')
# 287 NASDAQ ('AEYE', 'STK', 'SMART', 'USD')
# 291 NASDAQ ('AEZS', 'STK', 'SMART', 'USD')
# 295 NASDAQ ('AFH', 'STK', 'SMART', 'USD')
# 299 NASDAQ ('AFHBL', 'STK', 'SMART', 'USD')
# 303 NASDAQ ('AFIN', 'STK', 'SMART', 'USD')
# 307 NASDAQ ('AFINP', 'STK', 'SMART', 'USD')
# 311 NASDAQ ('AFMD', 'STK', 'SMART', 'USD')
# 315 NASDAQ ('AFYA', 'STK', 'SMART', 'USD')
# 319 NASDAQ ('AGBA', 'STK', 'SMART', 'USD')
# 323 NASDAQ ('AGBAR', 'STK', 'SMART', 'USD')
# 327 NASDAQ ('AGBAU', 'STK', 'SMART', 'USD')
# 331 NASDAQ 
 'STK', 'SMART', 'USD')
# 287 NASDAQ ('ENSG', 'STK', 'SMART', 'USD')
# 291 NASDAQ ('ENSGV', 'STK', 'SMART', 'USD')
# 295 NASDAQ ('ENT', 'STK', 'SMART', 'USD')
# 299 NASDAQ ('ENTA', 'STK', 'SMART', 'USD')
# 303 NASDAQ ('ENTG', 'STK', 'SMART', 'USD')
# 307 NASDAQ ('ENTX', 'STK', 'SMART', 'USD')
# 311 NASDAQ ('ENZL', 'STK', 'SMART', 'USD')
# 315 NASDAQ ('EOLS', 'STK', 'SMART', 'USD')
# 319 NASDAQ ('EPAY', 'STK', 'SMART', 'USD')
# 323 NASDAQ ('EPIX', 'STK', 'SMART', 'USD')
# 327 NASDAQ ('EPSN', 'STK', 'SMART', 'USD')
# 331 NASDAQ ('EPZM', 'STK', 'SMART', 'USD')
# 335 NASDAQ ('EQ', 'STK', 'SMART', 'USD')
# 339 NASDAQ ('EQBK', 'STK', 'SMART', 'USD')
# 343 NASDAQ ('EQIX', 'STK', 'SMART', 'USD')
# 347 NASDAQ ('EQRR', 'STK', 'SMART', 'USD')
# 351 NASDAQ ('ERI', 'STK', 'SMART', 'USD')
# 355 NASDAQ ('ERIC', 'STK', 'SMART', 'USD')
# 359 NASDAQ ('ERIE', 'STK', 'SMART', 'USD')
# 363 NASDAQ ('ERII', 'STK', 'SMART', 'USD')
# 367 NASDAQ ('ERYP', 'STK', 'SMART', 'USD')
# 371 NASDAQ ('ESBK', 'STK', 'SMART', 'USD')
# 375 NASDAQ ('ESCA', 'STK', 'SMART', 'USD')
# 379 NASDAQ ('ESEA', 'STK', 'SMART', 'USD')
# 383 NASDAQ ('ESGD', 'STK', 'SMART', 'USD')
# 387 NASDAQ ('ESGE', 'STK', 'SMART', 'USD')
# 391 NASDAQ ('ESGG', 'STK', 'SMART', 'USD')
# 395 NASDAQ ('ESGR', 'STK', 'SMART', 'USD')
# 399 NASDAQ ('ESGRO', 'STK', 'SMART', 'USD')
# 3 NASDAQ ('ESGRP', 'STK', 'SMART', 'USD')
# 7 NASDAQ ('ESGU', 'STK', 'SMART', 'USD')
# 11 NASDAQ ('ESLT', 'STK', 'SMART', 'USD')
# 15 NASDAQ ('ESPR', 'STK', 'SMART', 'USD')
# 19 NASDAQ ('ESQ', 'STK', 'SMART', 'USD')
# 23 NASDAQ ('ESSA', 'STK', 'SMART', 'USD')
# 27 NASDAQ ('ESTA', 'STK', 'SMART', 'USD')
# 31 NASDAQ ('ESTR', 'STK', 'SMART', 'USD')
# 35 NASDAQ ('ESXB', 'STK', 'SMART', 'USD')
# 39 NASDAQ ('ETFC', 'STK', 'SMART', 'USD')
# 43 NASDAQ ('ETON', 'STK', 'SMART', 'USD')
# 47 NASDAQ ('ETSY', 'STK', 'SMART', 'USD')
# 51 NASDAQ ('ETTX', 'STK', 'SMART', 'USD')
# 55 NASDAQ ('EUFN', 'STK', 'SMART', 'USD')
# 59 NASDAQ ('EVBG', 'STK', 'SMART', 'USD')
# 63 NASDAQ ('EVER', 'STK', 'SMART', 'USD')
# 67 NASDAQ ('EVFM', 'STK', 'SMART', 'USD')
# 71 NASDAQ ('EVGBC', 'STK', 'SMART', 'USD')
# 75 NASDAQ ('EVGN', 'STK', 'SMART', 'USD')
# 79 NASDAQ ('EVK', 'STK', 'SMART', 'USD')
# 83 NASDAQ ('EVLMC', 'STK', 'SMART', 'USD')
# 87 NASDAQ ('EVLO', 'STK', 'SMART', 'USD')
# 91 NASDAQ ('EVOK', 'STK', 'SMART', 'USD')
# 95 NASDAQ ('EVOL', 'STK', 'SMART', 'USD')
# 99 NASDAQ ('EVOP', 'STK', 'SMART', 'USD')
# 103 NASDAQ ('EVSI', 'STK', 'SMART', 'USD')
# 107 NASDAQ ('EVSTC', 'STK', 'SMART', 'USD')
# 111 NASDAQ ('EWBC', 'STK', 'SMART', 'USD')
# 115 NASDAQ ('EWJE', 'STK', 'SMART', 'USD')
# 119 NASDAQ ('EWJV', 'STK', 'SMART', 'USD')
# 123 NASDAQ ('EWZS', 'STK', 'SMART', 'USD')
# 127 NASDAQ ('EXAS', 'STK', 'SMART', 'USD')
# 131 NASDAQ ('EXC', 'STK', 'SMART', 'USD')
# 135 NASDAQ ('EXEL', 'STK', 'SMART', 'USD')
# 139 NASDAQ ('EXFO', 'STK', 'SMART', 'USD')
# 143 NASDAQ ('EXLS', 'STK', 'SMART', 'USD')
# 147 NASDAQ ('EXPCU', 'STK', 'SMART', 'USD')
# 151 NASDAQ ('EXPD', 'STK', 'SMART', 'USD')
# 155 NASDAQ ('EXPE', 'STK', 'SMART', 'USD')
# 159 NASDAQ ('EXPI', 'STK', 'SMART', 'USD')
# 163 NASDAQ ('EXPO', 'STK', 'SMART', 'USD')
# 167 NASDAQ ('EXTR', 'STK', 'SMART', 'USD')
# 171 NASDAQ ('EYE', 'STK', 'SMART', 'USD')
# 175 NASDAQ ('EYEG', 'STK', 'SMART', 'USD')
# 179 NASDAQ ('EYEN', 'STK', 'SMART', 'USD')
# 183 NASDAQ ('EYES', 'STK', 'SMART', 'USD')
# 187 NASDAQ ('EYPT', 'STK', 'SMART', 'USD')
# 191 NASDAQ ('EZPW', 'STK', 'SMART', 'USD')
# 195 NASDAQ ('FAAR', 'STK', 'SMART', 'USD')
# 199 NASDAQ ('FAB', 'STK', 'SMART', 'USD')
# 203 NASDAQ ('FAD', 'STK', 'SMART', 'USD')
# 207 NASDAQ ('FALN', 'STK', 'SMART', 'USD')
# 211 NASDAQ ('FAMI', 'STK', 'SMART', 'USD')
# 215 NASDAQ ('FANG', 'STK', 'SMART', 'USD')
# 219 NASDAQ ('FANH', 'STK', 'SMART', 'USD')
# 223 NASDAQ ('FARM', 'STK', 'SMART', 'USD')
# 227 NASDAQ ('FARO', 'STK', 'SMART', 'USD')
# 231 NASDAQ ('FAST', 'STK', 'SMART', 'USD')
# 235 NASDAQ ('FAT', 'STK', 'SMART', 'USD')
# 239 NASDAQ ('FATE', 'STK', 'SMART', 'USD')
# 243 NASDAQ ('FB', 'STK', 'SMART', 'USD')
# 247 NASDAQ ('FBIO', 'STK', 'SMART', 'USD')
# 251 NASDAQ ('FBIOP', 'STK', 'SMART', 'USD')
# 255 NASDAQ ('FBIZ', 'STK', 'SMART', 'USD')
# 259 NASDAQ ('FBMS', 'STK', 'SMART', 'USD')
# 263 NASDAQ ('FBNC', 'STK', 'SMART', 'USD')
# 267 NASDAQ ('FBSS', 'STK', 'SMART', 'USD')
# 271 NASDAQ ('FBZ', 'STK', 'SMART', 'USD')
# 275 NASDAQ ('FCA', 'STK', 'SMART', 'USD')
# 279 NASDAQ ('FCAL', 'STK', 'SMART', 'USD')
# 283 NASDAQ ('FCAN', 'STK', 'SMART', 'USD')
# 287 NASDAQ ('FCAP', 'STK', 'SMART', 'USD')
# 291 NASDAQ ('FCBC', 'STK', 'SMART', 'USD')
# 295 NASDAQ ('FCBP', 'STK', 'SMART', 'USD')
# 299 NASDAQ ('FCCO', 'STK', 'SMART', 'USD')
# 303 NASDAQ ('FCCY', 'STK', 'SMART', 'USD')
# 307 NASDAQ ('FCEF', 'STK', 'SMART', 'USD')
# 311 NASDAQ ('FCEL', 'STK', 'SMART', 'USD')
# 315 NASDAQ ('FCFS', 'STK', 'SMART', 'USD')
# 319 NASDAQ ('FCNCA', 'STK', 'SMART', 'USD')
# 323 NASDAQ ('FCSC', 'STK', 'SMART', 'USD')
# 327 NASDAQ ('FCVT', 'STK', 'SMART', 'USD')
# 331 NASDAQ ('FDBC', 'STK', 'SMART', 'USD')
# 335 NASDAQ ('FDEF', 'STK', 'SMART', 'USD')
# 339 NASDAQ ('FDIV', 'STK', 'SMART', 'USD')
# 343 NASDAQ ('FDNI', 'STK', 'SMART', 'USD')
# 347 NASDAQ ('FDT', 'STK', 'SMART', 'USD')
# 351 NASDAQ ('FDTS', 'STK', 'SMART', 'USD')
# 355 NASDAQ ('FDUS', 'STK', 'SMART', 'USD')
# 359 NASDAQ ('FDUSL', 'STK', 'SMART', 'USD')
# 363 NASDAQ ('FDUSZ', 'STK', 'SMART', 'USD')
# 367 NASDAQ ('FEIM', 'STK', 'SMART', 'USD')
# 371 NASDAQ ('FELE', 'STK', 'SMART', 'USD')
# 375 NASDAQ ('FEM', 'STK', 'SMART', 'USD')
# 379 NASDAQ ('FEMB', 'STK', 'SMART', 'USD')
# 383 NASDAQ ('FEMS', 'STK', 'SMART', 'USD')
# 387 NASDAQ ('FENC', 'STK', 'SMART', 'USD')
# 391 NASDAQ ('FEP', 'STK', 'SMART', 'USD')
# 395 NASDAQ ('FEUZ', 'STK', 'SMART', 'USD')
# 399 NASDAQ ('FEX', 'STK', 'SMART', 'USD')
# 3 NASDAQ ('FEYE', 'STK', 'SMART', 'USD')
# 7 NASDAQ ('FFBC', 'STK', 'SMART', 'USD')
# 11 NASDAQ ('FFBW', 'STK', 'SMART', 'USD')
# 15 NASDAQ ('FFHL', 'STK', 'SMART', 'USD')
# 19 NASDAQ ('FFIC', 'STK', 'SMART', 'USD')
# 23 NASDAQ ('FFIN', 'STK', 'SMART', 'USD')
# 27 NASDAQ ('FFIV', 'STK', 'SMART', 'USD')
# 31 NASDAQ ('FFNW', 'STK', 'SMART', 'USD')
# 35 NASDAQ ('FFWM', 'STK', 'SMART', 'USD')
# 39 NASDAQ ('FGBI', 'STK', 'SMART', 'USD')
# 43 NASDAQ ('FGEN', 'STK', 'SMART', 'USD')
# 47 NASDAQ ('FGM', 'STK', 'SMART', 'USD')
# 51 NASDAQ ('FHB', 'STK', 'SMART', 'USD')
# 55 NASDAQ ('FHK', 'STK', 'SMART', 'USD')
# 59 NASDAQ ('FHL', 'STK', 'SMART', 'USD')
# 63 NASDAQ ('FIBK', 'STK', 'SMART', 'USD')
# 67 NASDAQ ('FID', 'STK', 'SMART', 'USD')
# 71 NASDAQ ('FINX', 'STK', 'SMART', 'USD')
# 75 NASDAQ ('FISI', 'STK', 'SMART', 'USD')
# 79 NASDAQ ('FISV', 'STK', 'SMART', 'USD')
# 83 NASDAQ ('FITB', 'STK', 'SMART', 'USD')
# 87 NASDAQ ('FITBI', 'STK', 'SMART', 'USD')
# 91 NASDAQ ('FITBP', 'STK', 'SMART', 'USD')
# ...
# 227 NYSE ('VKQ', 'STK', 'SMART', 'USD')
# 239 NYSE ('VLO', 'STK', 'SMART', 'USD')
# 243 NYSE ('VLRS', 'STK', 'SMART', 'USD')
# 251 NYSE ('VLT', 'STK', 'SMART', 'USD')
# 255 NYSE ('VLU', 'STK', 'SMART', 'USD')
# 259 NYSE ('VLUE', 'STK', 'SMART', 'USD')
# 279 NYSE ('VMC', 'STK', 'SMART', 'USD')
# 287 NYSE ('VMI', 'STK', 'SMART', 'USD')
# 291 NYSE ('VMM', 'STK', 'SMART', 'USD')
# 295 NYSE ('VMO', 'STK', 'SMART', 'USD')
# 299 NYSE ('VMOT', 'STK', 'SMART', 'USD')
# 303 NYSE ('VMW', 'STK', 'SMART', 'USD')
# 307 NYSE ('VNCE', 'STK', 'SMART', 'USD')
# 315 NYSE ('VNE', 'STK', 'SMART', 'USD')
# 323 NYSE ('VNLA', 'STK', 'SMART', 'USD')
# 327 NYSE ('VNM', 'STK', 'SMART', 'USD')
# 331 NYSE ('VNO', 'STK', 'SMART', 'USD')
# 335 NYSE ('VNO PRK', 'STK', 'SMART', 'USD')
# 339 NYSE ('VNO PRL', 'STK', 'SMART', 'USD')
# 343 NYSE ('VNO PRM', 'STK', 'SMART', 'USD')
# 351 NYSE ('VNQ', 'STK', 'SMART', 'USD')
# 359 NYSE ('VNRX', 'STK', 'SMART', 'USD')
# 363 NYSE ('VNTR', 'STK', 'SMART', 'USD')
# 367 NYSE ('VO', 'STK', 'SMART', 'USD')
# 371 NYSE ('VOC', 'STK', 'SMART', 'USD')
# 379 NYSE ('VOE', 'STK', 'SMART', 'USD')
# 383 NYSE ('VOLT', 'STK', 'SMART', 'USD')
# 399 NYSE ('VOO', 'STK', 'SMART', 'USD')
# 3 NYSE ('VOOG', 'STK', 'SMART', 'USD')
# 7 NYSE ('VOOV', 'STK', 'SMART', 'USD')
# 11 NYSE ('VOT', 'STK', 'SMART', 'USD')
# 15 NYSE ('VOX', 'STK', 'SMART', 'USD')
# 23 NYSE ('VOYA', 'STK', 'SMART', 'USD')
# 27 NYSE ('VOYA PRB', 'STK', 'SMART', 'USD')
# 31 NYSE ('VPC', 'STK', 'SMART', 'USD')
# 35 NYSE ('VPG', 'STK', 'SMART', 'USD')
# 39 NYSE ('VPL', 'STK', 'SMART', 'USD')
# 43 NYSE ('VPU', 'STK', 'SMART', 'USD')
# 47 NYSE ('VPV', 'STK', 'SMART', 'USD')
# 51 NYSE ('VQT', 'STK', 'SMART', 'USD')
# 59 NYSE ('VRAI', 'STK', 'SMART', 'USD')
# 95 NYSE ('VRP', 'STK', 'SMART', 'USD')
# 103 NYSE ('VRS', 'STK', 'SMART', 'USD')
# 127 NYSE ('VRTV', 'STK', 'SMART', 'USD')
# 147 NYSE ('VSGX', 'STK', 'SMART', 'USD')
# 151 NYSE ('VSH', 'STK', 'SMART', 'USD')
# 155 NYSE ('VSI', 'STK', 'SMART', 'USD')
# 159 NYSE ('VSL', 'STK', 'SMART', 'USD')
# 163 NYSE ('VSLR', 'STK', 'SMART', 'USD')
# 167 NYSE ('VSM', 'STK', 'SMART', 'USD')
# 175 NYSE ('VSS', 'STK', 'SMART', 'USD')
# 179 NYSE ('VST', 'STK', 'SMART', 'USD')
# 187 NYSE ('VSTO', 'STK', 'SMART', 'USD')
# 191 NYSE ('VT', 'STK', 'SMART', 'USD')
# 195 NYSE ('VTA', 'STK', 'SMART', 'USD')
# 203 NYSE ('VTEB', 'STK', 'SMART', 'USD')
# 215 NYSE ('VTI', 'STK', 'SMART', 'USD')
# 231 NYSE ('VTN', 'STK', 'SMART', 'USD')
# 239 NYSE ('VTR', 'STK', 'SMART', 'USD')
# 247 NYSE ('VTV', 'STK', 'SMART', 'USD')
# 267 NYSE ('VUG', 'STK', 'SMART', 'USD')
# 271 NYSE ('VUSE', 'STK', 'SMART', 'USD')
# 279 NYSE ('VV', 'STK', 'SMART', 'USD')
# 283 NYSE ('VVI', 'STK', 'SMART', 'USD')
# 291 NYSE ('VVR', 'STK', 'SMART', 'USD')
# 299 NYSE ('VVV', 'STK', 'SMART', 'USD')
# 303 NYSE ('VWO', 'STK', 'SMART', 'USD')
# 311 NYSE ('VXF', 'STK', 'SMART', 'USD')
# 323 NYSE ('VXX', 'STK', 'SMART', 'USD')
# 327 NYSE ('VXZ', 'STK', 'SMART', 'USD')
# 335 NYSE ('VYM', 'STK', 'SMART', 'USD')
# 343 NYSE ('VZ', 'STK', 'SMART', 'USD')
# 347 NYSE ('W', 'STK', 'SMART', 'USD')
# 351 NYSE ('WAAS', 'STK', 'SMART', 'USD')
# 355 NYSE ('WAB', 'STK', 'SMART', 'USD')
# 371 NYSE ('WAIR', 'STK', 'SMART', 'USD')
# 375 NYSE ('WAL', 'STK', 'SMART', 'USD')
# 379 NYSE ('WALA', 'STK', 'SMART', 'USD')
# 383 NYSE ('WANT', 'STK', 'SMART', 'USD')
# 391 NYSE ('WAT', 'STK', 'SMART', 'USD')
# 7 NYSE ('WBAI', 'STK', 'SMART', 'USD')
# 11 NYSE ('WBAL', 'STK', 'SMART', 'USD')
# 15 NYSE ('WBC', 'STK', 'SMART', 'USD')
# 19 NYSE ('WBIA', 'STK', 'SMART', 'USD')
# 23 NYSE ('WBIB', 'STK', 'SMART', 'USD')
# 27 NYSE ('WBIC', 'STK', 'SMART', 'USD')
# 31 NYSE ('WBID', 'STK', 'SMART', 'USD')
# 35 NYSE ('WBIE', 'STK', 'SMART', 'USD')
# 39 NYSE ('WBIF', 'STK', 'SMART', 'USD')
# 43 NYSE ('WBIG', 'STK', 'SMART', 'USD')
# 47 NYSE ('WBII', 'STK', 'SMART', 'USD')
# 51 NYSE ('WBIL', 'STK', 'SMART', 'USD')
# 55 NYSE ('WBIN', 'STK', 'SMART', 'USD')
# 59 NYSE ('WBIT', 'STK', 'SMART', 'USD')
# 63 NYSE ('WBIY', 'STK', 'SMART', 'USD')
# 67 NYSE ('WBK', 'STK', 'SMART', 'USD')
# 75 NYSE ('WBS', 'STK', 'SMART', 'USD')
# 79 NYSE ('WBS PRF', 'STK', 'SMART', 'USD')
# 83 NYSE ('WBT', 'STK', 'SMART', 'USD')
# 87 NYSE ('WCC', 'STK', 'SMART', 'USD')
# 91 NYSE ('WCG', 'STK', 'SMART', 'USD')
# 95 NYSE ('WCHN', 'STK', 'SMART', 'USD')
# 103 NYSE ('WCN', 'STK', 'SMART', 'USD')
# 107 NYSE ('WD', 'STK', 'SMART', 'USD')
# 123 NYSE ('WDIV', 'STK', 'SMART', 'USD')
# 127 NYSE ('WDR', 'STK', 'SMART', 'USD')
# 131 NYSE ('WDRW', 'STK', 'SMART', 'USD')
# 135 NYSE ('WEA', 'STK', 'SMART', 'USD')
# 139 NYSE ('WEAT', 'STK', 'SMART', 'USD')
# 147 NYSE ('WEC', 'STK', 'SMART', 'USD')
# 151 NYSE ('WEI', 'STK', 'SMART', 'USD')
# 155 NYSE ('WELL', 'STK', 'SMART', 'USD')
# 167 NYSE ('WES', 'STK', 'SMART', 'USD')
# 175 NYSE ('WEX', 'STK', 'SMART', 'USD')
# 183 NYSE ('WF', 'STK', 'SMART', 'USD')
# 187 NYSE ('WFC', 'STK', 'SMART', 'USD')
# 191 NYSE ('WFC PRL', 'STK', 'SMART', 'USD')
# 195 NYSE ('WFC PRN', 'STK', 'SMART', 'USD')
# 199 NYSE ('WFC PRO', 'STK', 'SMART', 'USD')
# 203 NYSE ('WFC PRP', 'STK', 'SMART', 'USD')
# 207 NYSE ('WFC PRQ', 'STK', 'SMART', 'USD')
# 211 NYSE ('WFC PRR', 'STK', 'SMART', 'USD')
# 215 NYSE ('WFC PRT', 'STK', 'SMART', 'USD')
# 219 NYSE ('WFC PRV', 'STK', 'SMART', 'USD')
# 223 NYSE ('WFC PRW', 'STK', 'SMART', 'USD')
# 227 NYSE ('WFC PRX', 'STK', 'SMART', 'USD')
# 231 NYSE ('WFC PRY', 'STK', 'SMART', 'USD')
# 235 NYSE ('WFE PRA', 'STK', 'SMART', 'USD')
# 239 NYSE ('WFHY', 'STK', 'SMART', 'USD')
# 243 NYSE ('WFIG', 'STK', 'SMART', 'USD')
# 247 NYSE ('WGO', 'STK', 'SMART', 'USD')
# 251 NYSE ('WH', 'STK', 'SMART', 'USD')
# 255 NYSE ('WHD', 'STK', 'SMART', 'USD')
# 267 NYSE ('WHG', 'STK', 'SMART', 'USD')
# 287 NYSE ('WHR', 'STK', 'SMART', 'USD')
# 291 NYSE ('WIA', 'STK', 'SMART', 'USD')
# 299 NYSE ('WIL', 'STK', 'SMART', 'USD')
# 323 NYSE ('WIP', 'STK', 'SMART', 'USD')
# 335 NYSE ('WIT', 'STK', 'SMART', 'USD')
# 339 NYSE ('WIW', 'STK', 'SMART', 'USD')
# 347 NYSE ('WK', 'STK', 'SMART', 'USD')
# 359 NYSE ('WLDR', 'STK', 'SMART', 'USD')
# 367 NYSE ('WLH', 'STK', 'SMART', 'USD')
# 371 NYSE ('WLK', 'STK', 'SMART', 'USD')
# 375 NYSE ('WLKP', 'STK', 'SMART', 'USD')
# 379 NYSE ('WLL', 'STK', 'SMART', 'USD')
# 387 NYSE ('WM', 'STK', 'SMART', 'USD')
# 391 NYSE ('WMB', 'STK', 'SMART', 'USD')
# 395 NYSE ('WMC', 'STK', 'SMART', 'USD')
# 3 NYSE ('WMK', 'STK', 'SMART', 'USD')
# 7 NYSE ('WMS', 'STK', 'SMART', 'USD')
# 11 NYSE ('WMT', 'STK', 'SMART', 'USD')
# 15 NYSE ('WNC', 'STK', 'SMART', 'USD')
# 23 NYSE ('WNS', 'STK', 'SMART', 'USD')
# 27 NYSE ('WOMN', 'STK', 'SMART', 'USD')
# 35 NYSE ('WOR', 'STK', 'SMART', 'USD')
# 39 NYSE ('WORK', 'STK', 'SMART', 'USD')
# 47 NYSE ('WOW', 'STK', 'SMART', 'USD')
# 51 NYSE ('WPC', 'STK', 'SMART', 'USD')
# 55 NYSE ('WPG', 'STK', 'SMART', 'USD')
# 59 NYSE ('WPG PRH', 'STK', 'SMART', 'USD')
# 63 NYSE ('WPG PRI', 'STK', 'SMART', 'USD')
# 67 NYSE ('WPM', 'STK', 'SMART', 'USD')
# 71 NYSE ('WPP', 'STK', 'SMART', 'USD')
# 79 NYSE ('WPS', 'STK', 'SMART', 'USD')
# 83 NYSE ('WPX', 'STK', 'SMART', 'USD')
# 87 NYSE ('WRB', 'STK', 'SMART', 'USD')
# 91 NYSE ('WRB PRB', 'STK', 'SMART', 'USD')
# 95 NYSE ('WRB PRC', 'STK', 'SMART', 'USD')
# 99 NYSE ('WRB PRD', 'STK', 'SMART', 'USD')
# 103 NYSE ('WRB PRE', 'STK', 'SMART', 'USD')
# 107 NYSE ('WRE', 'STK', 'SMART', 'USD')
# 111 NYSE ('WRI', 'STK', 'SMART', 'USD')
# 115 NYSE ('WRK', 'STK', 'SMART', 'USD')
# 135 NYSE ('WRN', 'STK', 'SMART', 'USD')
# 163 NYSE ('WSM', 'STK', 'SMART', 'USD')
# 167 NYSE ('WSO', 'STK', 'SMART', 'USD')
# 171 NYSE ('WSO B', 'STK', 'SMART', 'USD')
# 175 NYSE ('WSR', 'STK', 'SMART', 'USD')
# 179 NYSE ('WST', 'STK', 'SMART', 'USD')
# 207 NYSE ('WTI', 'STK', 'SMART', 'USD')
# 211 NYSE ('WTID', 'STK', 'SMART', 'USD')
# 215 NYSE ('WTIU', 'STK', 'SMART', 'USD')
# 219 NYSE ('WTM', 'STK', 'SMART', 'USD')
# 223 NYSE ('WTMF', 'STK', 'SMART', 'USD')
# 227 NYSE ('WTR', 'STK', 'SMART', 'USD')
# 243 NYSE ('WTRU', 'STK', 'SMART', 'USD')
# 247 NYSE ('WTS', 'STK', 'SMART', 'USD')
# 251 NYSE ('WTT', 'STK', 'SMART', 'USD')
# 255 NYSE ('WTTR', 'STK', 'SMART', 'USD')
# 259 NYSE ('WU', 'STK', 'SMART', 'USD')
# 263 NYSE ('WUBA', 'STK', 'SMART', 'USD')
# 291 NYSE ('WWE', 'STK', 'SMART', 'USD')
# 299 NYSE ('WWW', 'STK', 'SMART', 'USD')
# 303 NYSE ('WY', 'STK', 'SMART', 'USD')
# 307 NYSE ('WYND', 'STK', 'SMART', 'USD')
# 315 NYSE ('WYY', 'STK', 'SMART', 'USD')
# 319 NYSE ('X', 'STK', 'SMART', 'USD')
# 327 NYSE ('XAN', 'STK', 'SMART', 'USD')
# 331 NYSE ('XAN PRC', 'STK', 'SMART', 'USD')
# 335 NYSE ('XAR', 'STK', 'SMART', 'USD')
# 339 NYSE ('XBI', 'STK', 'SMART', 'USD')
# 351 NYSE ('XBUY', 'STK', 'SMART', 'USD')
# 355 NYSE ('XCEM', 'STK', 'SMART', 'USD')
# 359 NYSE ('XCOM', 'STK', 'SMART', 'USD')
# 367 NYSE ('XDIV', 'STK', 'SMART', 'USD')
# 371 NYSE ('XEC', 'STK', 'SMART', 'USD')
# 399 NYSE ('XES', 'STK', 'SMART', 'USD')
# 3 NYSE ('XFLT', 'STK', 'SMART', 'USD')
# 15 NYSE ('XHB', 'STK', 'SMART', 'USD')
# 19 NYSE ('XHE', 'STK', 'SMART', 'USD')
# 23 NYSE ('XHR', 'STK', 'SMART', 'USD')
# 27 NYSE ('XHS', 'STK', 'SMART', 'USD')
# 31 NYSE ('XIN', 'STK', 'SMART', 'USD')
# 35 NYSE ('XITK', 'STK', 'SMART', 'USD')
# 39 NYSE ('XLB', 'STK', 'SMART', 'USD')
# 43 NYSE ('XLC', 'STK', 'SMART', 'USD')
# 47 NYSE ('XLE', 'STK', 'SMART', 'USD')
# 51 NYSE ('XLEY', 'STK', 'SMART', 'USD')
# 55 NYSE ('XLF', 'STK', 'SMART', 'USD')
# 59 NYSE ('XLG', 'STK', 'SMART', 'USD')
# 63 NYSE ('XLI', 'STK', 'SMART', 'USD')
# 67 NYSE ('XLK', 'STK', 'SMART', 'USD')
# 75 NYSE ('XLP', 'STK', 'SMART', 'USD')
# 79 NYSE ('XLRE', 'STK', 'SMART', 'USD')
# 87 NYSE ('XLSR', 'STK', 'SMART', 'USD')
# 91 NYSE ('XLSY', 'STK', 'SMART', 'USD')
# 95 NYSE ('XLTY', 'STK', 'SMART', 'USD')
# 99 NYSE ('XLU', 'STK', 'SMART', 'USD')
# 103 NYSE ('XLUY', 'STK', 'SMART', 'USD')
# 107 NYSE ('XLV', 'STK', 'SMART', 'USD')
# 111 NYSE ('XLY', 'STK', 'SMART', 'USD')
# 115 NYSE ('XME', 'STK', 'SMART', 'USD')
# 119 NYSE ('XMHQ', 'STK', 'SMART', 'USD')
# 123 NYSE ('XMLV', 'STK', 'SMART', 'USD')
# 127 NYSE ('XMMO', 'STK', 'SMART', 'USD')
# 131 NYSE ('XMPT', 'STK', 'SMART', 'USD')
# 135 NYSE ('XMVM', 'STK', 'SMART', 'USD')
# 139 NYSE ('XMX', 'STK', 'SMART', 'USD')
# 151 NYSE ('XNTK', 'STK', 'SMART', 'USD')
# 159 NYSE ('XOM', 'STK', 'SMART', 'USD')
# 175 NYSE ('XOP', 'STK', 'SMART', 'USD')
# 187 NYSE ('XPH', 'STK', 'SMART', 'USD')
# 191 NYSE ('XPL', 'STK', 'SMART', 'USD')
# 195 NYSE ('XPO', 'STK', 'SMART', 'USD')
# 199 NYSE ('XPP', 'STK', 'SMART', 'USD')
# 207 NYSE ('XRF', 'STK', 'SMART', 'USD')
# 211 NYSE ('XRLV', 'STK', 'SMART', 'USD')
# 215 NYSE ('XRT', 'STK', 'SMART', 'USD')
# 219 NYSE ('XRX', 'STK', 'SMART', 'USD')
# 223 NYSE ('XSD', 'STK', 'SMART', 'USD')
# 227 NYSE ('XSHD', 'STK', 'SMART', 'USD')
# 231 NYSE ('XSHQ', 'STK', 'SMART', 'USD')
# 235 NYSE ('XSLV', 'STK', 'SMART', 'USD')
# 239 NYSE ('XSMO', 'STK', 'SMART', 'USD')
# 243 NYSE ('XSOE', 'STK', 'SMART', 'USD')
# 247 NYSE ('XSPA', 'STK', 'SMART', 'USD')
# 251 NYSE ('XSVM', 'STK', 'SMART', 'USD')
# 255 NYSE ('XSW', 'STK', 'SMART', 'USD')
# 259 NYSE ('XT', 'STK', 'SMART', 'USD')
# 263 NYSE ('XTH', 'STK', 'SMART', 'USD')
# 267 NYSE ('XTL', 'STK', 'SMART', 'USD')
# 271 NYSE ('XTLB', 'STK', 'SMART', 'USD')
# 275 NYSE ('XTN', 'STK', 'SMART', 'USD')
# 279 NYSE ('XTNT', 'STK', 'SMART', 'USD')
# 283 NYSE ('XVZ', 'STK', 'SMART', 'USD')
# 287 NYSE ('XWEB', 'STK', 'SMART', 'USD')
# 291 NYSE ('XXII', 'STK', 'SMART', 'USD')
# 295 NYSE ('XYF', 'STK', 'SMART', 'USD')
# 299 NYSE ('XYL', 'STK', 'SMART', 'USD')
# 303 NYSE ('Y', 'STK', 'SMART', 'USD')
# 307 NYSE ('YANG', 'STK', 'SMART', 'USD')
# 311 NYSE ('YCBD', 'STK', 'SMART', 'USD')
# 315 NYSE ('YCL', 'STK', 'SMART', 'USD')
# 319 NYSE ('YCOM', 'STK', 'SMART', 'USD')
# 323 NYSE ('YCS', 'STK', 'SMART', 'USD')
# 327 NYSE ('YELP', 'STK', 'SMART', 'USD')
# 331 NYSE ('YETI', 'STK', 'SMART', 'USD')
# 335 NYSE ('YEXT', 'STK', 'SMART', 'USD')
# 339 NYSE ('YGRN', 'STK', 'SMART', 'USD')
# 343 NYSE ('YGYI', 'STK', 'SMART', 'USD')
# 347 NYSE ('YGYIP', 'STK', 'SMART', 'USD')
# 351 NYSE ('YI', 'STK', 'SMART', 'USD')
# 355 NYSE ('YIN', 'STK', 'SMART', 'USD')
# 359 NYSE ('YINN', 'STK', 'SMART', 'USD')
# 363 NYSE ('YJ', 'STK', 'SMART', 'USD')
# 367 NYSE ('YLCO', 'STK', 'SMART', 'USD')
# 371 NYSE ('YLD', 'STK', 'SMART', 'USD')
# [('AABA', 'STK', 'SMART', 'USD'), ('AAL', 'STK', 'SMART', 'USD'), ('AAME', 'STK', 'SMART', 'USD'), ('AAOI', 'STK', 'SMART', 'USD'), ('AAON', 'STK', 'SMART', 'USD'), ('AAPL', 'STK', 'SMART', 'USD'), ('AAWW', 'STK', 'SMART', 'USD'), ('AAXJ', 'STK', 'SMART', 'USD'), ('AAXN', 'STK', 'SMART', 'USD'), ('ABCB', 'STK', 'SMART', 'USD'), ('ABDC', 'STK', 'SMART', 'USD'), ('ABEO', 'STK', 'SMART', 'USD'), ('ABIL', 'STK', 'SMART', 'USD'), ('ABIO', 'STK', 'SMART', 'USD'), ('ABMD', 'STK', 'SMART', 'USD'), ('ABTX', 'STK', 'SMART', 'USD'), ('ABUS', 'STK', 'SMART', 'USD'), ('ACAD', 'STK', 'SMART', 'USD'), ('ACAM', 'STK', 'SMART', 'USD'), ('ACAMU', 'STK', 'SMART', 'USD'), ('ACBI', 'STK', 'SMART', 'USD'), ('ACER', 'STK', 'SMART', 'USD'), ('ACGL', 'STK', 'SMART', 'USD'), ('ACGLO', 'STK', 'SMART', 'USD'), ('ACGLP', 'STK', 'SMART', 'USD'), ('ACHC', 'STK', 'SMART', 'USD'), ('ACHN', 'STK', 'SMART', 'USD'), ('ACHV', 'STK', 'SMART', 'USD'), ('ACIA', 'STK', 'SMART', 'USD'), ('ACIU', 'STK', 'SMART', 'USD'), ('ACIW', 'STK', 'SMART', 'USD'), ('ACLS', 'STK', 'SMART', 'USD'), ('ACMR', 'STK', 'SMART', 'USD'), ('ACNB', 'STK', 'SMART', 'USD'), ('ACOR', 'STK', 'SMART', 'USD'), ('ACRS', 'STK', 'SMART', 'USD'), ('ACRX', 'STK', 'S
', 'STK', 'SMART', 'USD'), ('AINV', 'STK', 'SMART', 'USD'), ('AIQ', 'STK', 'SMART', 'USD'), ('AIRG', 'STK', 'SMART', 'USD'), ('AIRR', 'STK', 'SMART', 'USD'), ('AIRT', 'STK', 'SMART', 'USD'), ('AIRTP', 'STK', 'SMART', 'USD'), ('AKAM', 'STK', 'SMART', 'USD'), ('AKBA', 'STK', 'SMART', 'USD'), ('AKCA', 'STK', 'SMART', 'USD'), ('AKER', 'STK', 'SMART', 'USD'), ('AKRO', 'STK', 'SMART', 'USD'), ('AKRX', 'STK', 'SMART', 'USD'), ('AKTS', 'STK', 'SMART', 'USD'), ('AKTX', 'STK', 'SMART', 'USD'), ('ALAC', 'STK', 'SMART', 'USD'), ('ALACR', 'STK', 'SMART', 'USD'), ('ALACU', 'STK', 'SMART', 'USD'), ('ALBO', 'STK', 'SMART', 'USD'), ('ALCO', 'STK', 'SMART', 'USD'), ('ALDR', 'STK', 'SMART', 'USD'),  ...
# 0       (AABA, STK, SMART, USD)
# 1        (AAL, STK, SMART, USD)
# 2       (AAME, STK, SMART, USD)
# 3       (AAOI, STK, SMART, USD)
# 4       (AAON, STK, SMART, USD)
#                  ...
# 8591     (YIN, STK, SMART, USD)
# 8592    (YINN, STK, SMART, USD)
# 8593      (YJ, STK, SMART, USD)
# 8594    (YLCO, STK, SMART, USD)
# 8595     (YLD, STK, SMART, USD)
# Length: 8596, dtype: object

# %% [markdown]
# #### El siguiente bloque de codigo, reune la extraccion de datos y limpieza con la insercion de los datos en la base de datos, al igual se manejo con Clases y Objetos
#
# #### The next block of code, gathers the data extraction and cleaning with the insertion of the data in the database, as well as handling with Classes and Objects

# %%
import requests
import csv
from bs4 import BeautifulSoup
import os
import pandas as pd 
import psycopg2
      
class DATABASE():
    def __init__(self):
        self.user="postgres"
        self.password = "admin"
        self.host = "localhost"
        self.port = "5432"
        self.database = "aplicacionPy"
        
    def conectar(self):
        try:
            connection = psycopg2.connect(user = self.user,
                                          password = self.password,
                                          host = self.host,
                                          port = self.port,
                                          database = self.database)

            cursor = connection.cursor()
            print ( connection.get_dsn_parameters(),"\n")

            cursor.execute("SELECT version();")
            record = cursor.fetchone()
            print("You are connected to - ", record,"\n")
            return connection
        except (Exception, psycopg2.Error) as error :
            print ("Error while connecting to PostgreSQL", error)
            return error
    def desconectar(self):
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
            
    def crear_tabla(self):
        try:
            connection = self.conectar()

            cursor = connection.cursor()

            create_table_query = '''CREATE TABLE public."RESULTS_CURRENCY"
                (
                    "IBSymbol" character varying NOT NULL,
                    "STK" character varying NOT NULL,
                    "SMART" character varying NOT NULL,
                    "Currency" character varying NOT NULL
                )
                WITH (
                    OIDS = FALSE
                );
                ALTER TABLE public."RESULTS"
                    OWNER to postgres;'''
            cursor.execute(create_table_query)
            connection.commit()
            print("Table created successfully in PostgreSQL ")
        except (Exception, psycopg2.DatabaseError) as error :
            print ("Error while creating PostgreSQL table", error)
            
    def insert(self,value1,value2,value3,value4):
        try:
            connection=self.conectar()
            cursor = connection.cursor()
            cursor.execute("INSERT INTO public.\"RESULTS_CURRENCY\" (\"IBSymbol\", \"STK\", \"SMART\",\"Currency\") VALUES(%s, %s, %s, %s)", (value1, value2, value3,value4))
            connection.commit()
            cursor.close()
            connection.close()
            print ("Record inserted successfully into mobile table")
        except (Exception, psycopg2.Error) as error :
            if(connection):
                print("Failed to insert record into mobile table", error)
                
file = open('symbols.csv', 'w')
file.truncate()
writer = csv.writer(file)
values_exchange = []

class Exchange:
    def __init__(self,url,page_max,ran_endC,name_exchange):
        self.url=url
        self.page_max=page_max
        self.ran_endC=ran_endC
        self.name_exchange=name_exchange
        
    def extract_data(self):
        database=DATABASE()
        for page in range(1, self.page_max):
            response  = requests.get(self.url + str(page))
            data = response.text
            soup = BeautifulSoup(data, features='lxml')
            html = str(soup.contents)
            html_preprocess = html.split('<td>')
            if page < self.page_max-1:
                ran_ini = 3
                ran_end = 400
            else:
                ran_ini = 3
                ran_end = self.ran_endC
            for i in range(ran_ini,ran_end)[0::4]:
                values = (html_preprocess[i][:-6], 'STK', 'SMART', html_preprocess[i+1][:3])
                database.insert(html_preprocess[i][:-6], 'STK', 'SMART', html_preprocess[i+1][:3])
                if values not in values_exchange:
                    print(i, self.name_exchange, values)
                    values_exchange.append(values)

urls=['https://www.interactivebrokers.com/en/index.php?f=2222&exch=nasdaq&showcategories=STK&p=&cc=&limit=100&page=','https://www.interactivebrokers.com/en/index.php?f=2222&exch=nyse&showcategories=STK&p=&cc=&limit=100&page=','https://www.interactivebrokers.com/en/index.php?f=2222&exch=amex&showcategories=STK&p=&cc=&limit=100&page=']

db=DATABASE()
db.crear_tabla()
exchange_nasdaq=Exchange(urls[0],35,15,'NASDAQ')                    
exchange_nasdaq.extract_data()

exchange_nyse=Exchange(urls[1],87,372,'NYSE')                    
exchange_nyse.extract_data()

exchange_amex=Exchange(urls[2],87,368,'AMEX')                    
exchange_amex.extract_data()
# Out:
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 3 NASDAQ ('AABA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 7 NASDAQ ('AAL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 11 NASDAQ ('AAME', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 15 NASDAQ ('AAOI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 19 NASDAQ ('AAON', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 23 NASDAQ ('AAPL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 27 NASDAQ ('AAWW', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 31 NASDAQ ('AAXJ', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 35 NASDAQ ('AAXN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 39 NASDAQ ('ABCB', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 43 NASDAQ ('ABDC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 47 NASDAQ ('ABEO', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 51 NASDAQ ('ABIL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 55 NASDAQ ('ABIO', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 59 NASDAQ ('ABMD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 63 NASDAQ ('ABTX', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 67 NASDAQ ('ABUS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 71 NASDAQ ('ACAD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 75 NASDAQ ('ACAM', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 79 NASDAQ ('ACAMU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 83 NASDAQ ('ACBI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 87 NASDAQ ('ACER', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 91 NASDAQ ('ACGL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 95 NASDAQ ('ACGLO', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 99 NASDAQ ('ACGLP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 103 NASDAQ ('ACHC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 107 NASDAQ ('ACHN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 111 NASDAQ ('ACHV', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 115 NASDAQ ('ACIA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 119 NASDAQ ('ACIU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 123 NASDAQ ('ACIW', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 127 NASDAQ ('ACLS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 131 NASDAQ ('ACMR', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 135 NASDAQ ('ACNB', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 139 NASDAQ ('ACOR', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 143 NASDAQ ('ACRS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 147 NASDAQ ('ACRX', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 151 NASDAQ ('ACST', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 155 NASDAQ ('ACT', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 159 NASDAQ ('ACTG', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 163 NASDAQ ('ACTT', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 167 NASDAQ ('ACTTU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 171 NASDAQ ('ACWI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 175 NASDAQ ('ACWX', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 179 NASDAQ ('ADAP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 183 NASDAQ ('ADBE', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 187 NASDAQ ('ADES', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 191 NASDAQ ('ADI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 195 NASDAQ ('ADIL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 199 NASDAQ ('ADMA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 203 NASDAQ ('ADMP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 207 NASDAQ ('ADMS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 211 NASDAQ ('ADP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 215 NASDAQ ('ADPT', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 219 NASDAQ ('ADRA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 223 NASDAQ ('ADRD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 227 NASDAQ ('ADRE', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 231 NASDAQ ('ADRO', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 235 NASDAQ ('ADRU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 239 NASDAQ ('ADSK', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 243 NASDAQ ('ADTN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 247 NASDAQ ('ADUS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 251 NASDAQ ('ADVM', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 255 NASDAQ ('ADXS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 259 NASDAQ ('AEGN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 263 NASDAQ ('AEHR', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 267 NASDAQ ('AEIS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 271 NASDAQ ('AEMD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 275 NASDAQ ('AERI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 279 NASDAQ ('AESE', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 283 NASDAQ ('AEY', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 287 NASDAQ ('AEYE', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 291 NASDAQ ('AEZS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 295 NASDAQ ('AFH', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 299 NASDAQ ('AFHBL', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 303 NASDAQ ('AFIN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 307 NASDAQ ('AFINP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 311 NASDAQ ('AFMD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 315 NASDAQ ('AFYA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 319 NASDAQ ('AGBA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 323 NASDAQ ('AGBAR', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 327 NASDAQ ('AGBAU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 331 NASDAQ ('AGEN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 335 NASDAQ ('AGFS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 339 NASDAQ ('AGIO', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 343 NASDAQ ('AGLE', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 347 NASDAQ ('AGMH', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 351 NASDAQ ('AGNC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 355 NASDAQ ('AGNCB', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 359 NASDAQ ('AGNCM', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 363 NASDAQ ('AGNCN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 367 NASDAQ ('AGND', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 371 NASDAQ ('AGRX', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 375 NASDAQ ('AGTC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 379 NASDAQ ('AGYS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 383 NASDAQ ('AGZD', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 387 NASDAQ ('AHPI', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 391 NASDAQ ('AIA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 395 NASDAQ ('AIHS', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 399 NASDAQ ('AIMC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 3 NYSE ('A', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 7 NYSE ('AA', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 11 NYSE ('AAAU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 19 NYSE ('AAC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 23 NYSE ('AADR', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 31 NYSE ('AAMC', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 39 NYSE ('AAN', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 51 NYSE ('AAP', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 59 NYSE ('AAT', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 63 NYSE ('AAU', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 79 NYSE ('AB', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 83 NYSE ('ABB', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 87 NYSE ('ABBV', 'STK', 'SMART', 'USD')
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# 91 NYSE ('ABC', 'STK', 'SMART', 'USD')
# ...
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
# {'user': 'postgres', 'dbname': 'aplicacionPy', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 10.8, compiled by Visual C++ build 1800, 64-bit',)
#
# Record inserted successfully into mobile table
